# %%
# %matplotlib inline
import seaborn as sns; sns.set(style="ticks", color_codes=True)
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import gridspec
import scipy
style.use('ggplot')
import datetime
from io import StringIO
import re
import numpy as np
from datetime import datetime
import math
from matplotlib.texmanager import TexManager


sns.set_style('whitegrid')
sns.set_palette('colorblind')
FIG_SIZE = (12, 3)
TexManager.font_info['Times New Roman'] = ('Times New Roman', r'\usepackage{Times New Roman}')

font = {'family' : 'Times New Roman',
        'weight' : 'bold',
        'size'   : 30}
plt.rc('font', **font)
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['text.usetex'] = True

plt.rcParams['xtick.labelsize'] = 22
plt.rcParams['ytick.labelsize'] = 22
plt.rcParams['axes.labelsize']= 22
plt.rcParams['lines.linewidth']= 2
plt.rcParams['lines.markersize']= 2

# %%
tabs = {'00001': 551,
 '00010': 217,
 '00011': 138,
 '00100': 604,
 '00101': 392,
 '00110': 195,
 '00111': 132,
 '01000': 393,
 '01001': 341,
 '01010': 77,
 '01011': 71,
 '01100': 240,
 '01101': 217,
 '01110': 74,
 '01111': 69,
 '10000': 257,
 '10001': 157,
 '10010': 191,
 '10011': 126,
 '10100': 228,
 '10101': 149,
 '10110': 175,
 '10111': 120,
 '11000': 95,
 '11001': 85,
 '11010': 71,
 '11011': 65,
 '11100': 90,
 '11101': 81,
 '11110': 68,
 '11111': 63}

{'community interest': 10000,
 'downloads': 1000,
 'stars npm': 100,
 'subscribers': 10,
 'repo runtime': 1,}

# %matplotlib inline
#https://github.com/tctianchi/pyvenn
import venn
plt.rcParams['text.usetex'] = False
font = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 18}
plt.rc('font', **font)

plt.rcParams['text.usetex'] = True

#labels = venn.get_labels([range(10), range(5, 15), range(3, 8), range(8, 17), range(10, 20)], fill=['number', 'logic'])
fig, ax = venn.venn5(tabs)
ax.legend('')
fig.set_size_inches(8,8)
#ax.figure.savefig('../../../seneca_research/npm_popularity/figures/venn_pop.pdf', bbox_inches='tight', facecolor='white')

# %%
number
# Out:
# {'community interest': 10000,
#  'downloads': 1000,
#  'repo runtime': 1,
#  'stars npm': 100,
#  'subscribers': 10}

# %%
npm.sort_values('dep_pro', ascending=False, inplace=True)
npm['dep_pro']=npm['dep_pro'].apply(int)
df=npm.head(1000).loc[:,[]]

# %%
#df.reset_index().to_csv('../../../top_depend_upon.csv', sep=';', index=True)

# %%
# Already prepared the data for the NPM_FINAL dataframe
#Filter: at least 700 days, github, 
npm_packages=pd.read_csv('../../popularity/csv/npm_popularity_2yearsOld.csv', sep=';', dtype=object, index_col='name')

npm_packages['first_release']=npm_packages['first_release'].apply(lambda x:
                                                                  float("".join(re.findall("[0-9.]+", x))) if 'day' in x 
                                                                  else float("".join(re.findall("[0-9.]+", x)))*30 if 'month' in x
                                                                  else (datetime.now().date() - 
                                                                        datetime.strptime(x, '%b %d, %Y').date()).days)

for x in npm_packages:
    #if x!= "first_release":
    npm_packages[x]=npm_packages[x].apply(float)
    npm_packages[x]=npm_packages[x].apply(float)
        

npm_packages.drop_duplicates(inplace=True)
npm_packages.drop('contributors', axis=1, inplace=True)

npm2=pd.read_csv('../../popularity/csv/only_npm.csv', sep=',', dtype=object, index_col=None)
npm2=npm2.loc[:,['Name','Repository URL']]
npm2=npm2.rename(columns = {'Name':'name','Repository URL':'url'})

npm2=npm2.set_index('name').merge(npm_packages,
                               left_index=True, 
                               right_index=True,
                               how='outer').dropna().reset_index()
npm2.dropna(inplace=True)

# %%
# remove duplicates, take only the popular ones with unique repository name
npm=npm2.sort_values('downloads', ascending=False)
npm['url']=npm['url'].apply(lambda x: x.split('/')[-2]+'-'+x.split('/')[-1])
npm=npm.groupby('url').first().reset_index()
npm.set_index('name', inplace=True)
npm.drop(['url','first_release','commits','dep_repo','dep_pro'], axis=1, inplace=True)
len(npm)
# Out:
# 175774

# %%
### add more metrics from librariesio
librariesio=pd.read_csv('../../popularity/csv/popularity_deps.csv', sep=';', dtype=object, index_col=None,  error_bad_lines=False)

npm=(npm.
     merge(librariesio.
           set_index('name'),
           left_index=True,
           right_index=True,
           how='left')
    )
len(npm)
# Out:
# 175774

# %%
npm = npm[['forks','stars_github','pulls_issues','subscribers',
           'transitive_runtime','repo_runtime','direct_runtime',
           'downloads', 'stars_npm']]

# %%
df_tmp=npm.fillna(0)
for x in df_tmp:
    #if x!= "first_release":
    df_tmp[x]=df_tmp[x].apply(float)
    print(x,len(df_tmp.query(str(x)+' == 0'))*100/len(df_tmp))
# Out:
# forks 49.67515104622982
# stars_github 31.993924016066085
# pulls_issues 42.93922878241378
# subscribers 5.121349004972294
# transitive_runtime 72.94082173700319
# repo_runtime 62.3323130838463
# direct_runtime 27.38118265500017
# downloads 0.01934302001433659
# stars_npm 76.25644293240184

# %%
df_tmp=npm.dropna()
df_tmp=df_tmp.loc[:,['transitive_runtime','repo_runtime','direct_runtime']]
df_tmp.dropna(inplace=True)
for x in df_tmp:
    #if x!= "first_release":
    df_tmp[x]=df_tmp[x].apply(float)
df_tmp.corr(method="pearson").style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row0_col0 {
#             background-color:  #b40426;
#         }    #T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row0_col1 {
#             background-color:  #3b4cc0;
#         }    #T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row0_col2 {
#             background-color:  #5673e0;
#         }    #T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row1_col0 {
#             background-color:  #3b4cc0;
#         }    #T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row1_col1 {
#             background-color:  #b40426;
#         }    #T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row1_col2 {
#             background-color:  #a5c3fe;
#         }    #T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row2_col0 {
#             background-color:  #3b4cc0;
#         }    #T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row2_col1 {
#             background-color:  #8caffe;
#         }    #T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row2_col2 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_5847a47c_104e_11e9_8fb3_5ce0c5eca063" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >transitive_runtime</th>
#         <th class="col_heading level0 col1" >repo_runtime</th>
#         <th class="col_heading level0 col2" >direct_runtime</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_5847a47c_104e_11e9_8fb3_5ce0c5eca063level0_row0" class="row_heading level0 row0" >transitive_runtime</th>
#         <td id="T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row0_col0" class="data row0 col0" >1.0</td>
#         <td id="T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row0_col1" class="data row0 col1" >0.58</td>
#         <td id="T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row0_col2" class="data row0 col2" >0.61</td>
#     </tr>    <tr>
#         <th id="T_5847a47c_104e_11e9_8fb3_5ce0c5eca063level0_row1" class="row_heading level0 row1" >repo_runtime</th>
#         <td id="T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row1_col0" class="data row1 col0" >0.58</td>
#         <td id="T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row1_col1" class="data row1 col1" >1.0</td>
#         <td id="T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row1_col2" class="data row1 col2" >0.71</td>
#     </tr>    <tr>
#         <th id="T_5847a47c_104e_11e9_8fb3_5ce0c5eca063level0_row2" class="row_heading level0 row2" >direct_runtime</th>
#         <td id="T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row2_col0" class="data row2 col0" >0.61</td>
#         <td id="T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row2_col1" class="data row2 col1" >0.71</td>
#         <td id="T_5847a47c_104e_11e9_8fb3_5ce0c5eca063row2_col2" class="data row2 col2" >1.0</td>
#     </tr></tbody>
# </table>

# %%
df_tmp.corr(method="spearman").style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_59828f46_104e_11e9_8fb3_5ce0c5eca063row0_col0 {
#             background-color:  #b40426;
#         }    #T_59828f46_104e_11e9_8fb3_5ce0c5eca063row0_col1 {
#             background-color:  #3b4cc0;
#         }    #T_59828f46_104e_11e9_8fb3_5ce0c5eca063row0_col2 {
#             background-color:  #92b4fe;
#         }    #T_59828f46_104e_11e9_8fb3_5ce0c5eca063row1_col0 {
#             background-color:  #3b4cc0;
#         }    #T_59828f46_104e_11e9_8fb3_5ce0c5eca063row1_col1 {
#             background-color:  #b40426;
#         }    #T_59828f46_104e_11e9_8fb3_5ce0c5eca063row1_col2 {
#             background-color:  #9ebeff;
#         }    #T_59828f46_104e_11e9_8fb3_5ce0c5eca063row2_col0 {
#             background-color:  #3b4cc0;
#         }    #T_59828f46_104e_11e9_8fb3_5ce0c5eca063row2_col1 {
#             background-color:  #485fd1;
#         }    #T_59828f46_104e_11e9_8fb3_5ce0c5eca063row2_col2 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_59828f46_104e_11e9_8fb3_5ce0c5eca063" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >transitive_runtime</th>
#         <th class="col_heading level0 col1" >repo_runtime</th>
#         <th class="col_heading level0 col2" >direct_runtime</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_59828f46_104e_11e9_8fb3_5ce0c5eca063level0_row0" class="row_heading level0 row0" >transitive_runtime</th>
#         <td id="T_59828f46_104e_11e9_8fb3_5ce0c5eca063row0_col0" class="data row0 col0" >1.0</td>
#         <td id="T_59828f46_104e_11e9_8fb3_5ce0c5eca063row0_col1" class="data row0 col1" >0.62</td>
#         <td id="T_59828f46_104e_11e9_8fb3_5ce0c5eca063row0_col2" class="data row0 col2" >0.72</td>
#     </tr>    <tr>
#         <th id="T_59828f46_104e_11e9_8fb3_5ce0c5eca063level0_row1" class="row_heading level0 row1" >repo_runtime</th>
#         <td id="T_59828f46_104e_11e9_8fb3_5ce0c5eca063row1_col0" class="data row1 col0" >0.62</td>
#         <td id="T_59828f46_104e_11e9_8fb3_5ce0c5eca063row1_col1" class="data row1 col1" >1.0</td>
#         <td id="T_59828f46_104e_11e9_8fb3_5ce0c5eca063row1_col2" class="data row1 col2" >0.73</td>
#     </tr>    <tr>
#         <th id="T_59828f46_104e_11e9_8fb3_5ce0c5eca063level0_row2" class="row_heading level0 row2" >direct_runtime</th>
#         <td id="T_59828f46_104e_11e9_8fb3_5ce0c5eca063row2_col0" class="data row2 col0" >0.72</td>
#         <td id="T_59828f46_104e_11e9_8fb3_5ce0c5eca063row2_col1" class="data row2 col1" >0.73</td>
#         <td id="T_59828f46_104e_11e9_8fb3_5ce0c5eca063row2_col2" class="data row2 col2" >1.0</td>
#     </tr></tbody>
# </table>

# %%
df_tmp=npm.dropna()
df_tmp=df_tmp.loc[:,['forks','stars_github','pulls_issues','subscribers']]
df_tmp.dropna(inplace=True)
for x in df_tmp:
    #if x!= "first_release":
    df_tmp[x]=df_tmp[x].apply(float)
df_tmp.corr(method="pearson").style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row0_col0 {
#             background-color:  #b40426;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row0_col1 {
#             background-color:  #eed0c0;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row0_col2 {
#             background-color:  #3b4cc0;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row0_col3 {
#             background-color:  #a1c0ff;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row1_col0 {
#             background-color:  #eed0c0;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row1_col1 {
#             background-color:  #b40426;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row1_col2 {
#             background-color:  #3b4cc0;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row1_col3 {
#             background-color:  #b1cbfc;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row2_col0 {
#             background-color:  #7a9df8;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row2_col1 {
#             background-color:  #7a9df8;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row2_col2 {
#             background-color:  #b40426;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row2_col3 {
#             background-color:  #3b4cc0;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row3_col0 {
#             background-color:  #cdd9ec;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row3_col1 {
#             background-color:  #d8dce2;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row3_col2 {
#             background-color:  #3b4cc0;
#         }    #T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row3_col3 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >forks</th>
#         <th class="col_heading level0 col1" >stars_github</th>
#         <th class="col_heading level0 col2" >pulls_issues</th>
#         <th class="col_heading level0 col3" >subscribers</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063level0_row0" class="row_heading level0 row0" >forks</th>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row0_col0" class="data row0 col0" >1.0</td>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row0_col1" class="data row0 col1" >0.85</td>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row0_col2" class="data row0 col2" >0.65</td>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row0_col3" class="data row0 col3" >0.76</td>
#     </tr>    <tr>
#         <th id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063level0_row1" class="row_heading level0 row1" >stars_github</th>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row1_col0" class="data row1 col0" >0.85</td>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row1_col1" class="data row1 col1" >1.0</td>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row1_col2" class="data row1 col2" >0.65</td>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row1_col3" class="data row1 col3" >0.77</td>
#     </tr>    <tr>
#         <th id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063level0_row2" class="row_heading level0 row2" >pulls_issues</th>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row2_col0" class="data row2 col0" >0.65</td>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row2_col1" class="data row2 col1" >0.65</td>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row2_col2" class="data row2 col2" >1.0</td>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row2_col3" class="data row2 col3" >0.56</td>
#     </tr>    <tr>
#         <th id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063level0_row3" class="row_heading level0 row3" >subscribers</th>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row3_col0" class="data row3 col0" >0.76</td>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row3_col1" class="data row3 col1" >0.77</td>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row3_col2" class="data row3 col2" >0.56</td>
#         <td id="T_d1c88758_104e_11e9_8fb3_5ce0c5eca063row3_col3" class="data row3 col3" >1.0</td>
#     </tr></tbody>
# </table>

# %%
df_tmp.corr(method="spearman").style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row0_col0 {
#             background-color:  #b40426;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row0_col1 {
#             background-color:  #e7d7ce;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row0_col2 {
#             background-color:  #cbd8ee;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row0_col3 {
#             background-color:  #3b4cc0;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row1_col0 {
#             background-color:  #ecd3c5;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row1_col1 {
#             background-color:  #b40426;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row1_col2 {
#             background-color:  #9abbff;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row1_col3 {
#             background-color:  #3b4cc0;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row2_col0 {
#             background-color:  #d7dce3;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row2_col1 {
#             background-color:  #9fbfff;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row2_col2 {
#             background-color:  #b40426;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row2_col3 {
#             background-color:  #3b4cc0;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row3_col0 {
#             background-color:  #506bda;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row3_col1 {
#             background-color:  #4055c8;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row3_col2 {
#             background-color:  #3b4cc0;
#         }    #T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row3_col3 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >forks</th>
#         <th class="col_heading level0 col1" >stars_github</th>
#         <th class="col_heading level0 col2" >pulls_issues</th>
#         <th class="col_heading level0 col3" >subscribers</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063level0_row0" class="row_heading level0 row0" >forks</th>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row0_col0" class="data row0 col0" >1.0</td>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row0_col1" class="data row0 col1" >0.86</td>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row0_col2" class="data row0 col2" >0.82</td>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row0_col3" class="data row0 col3" >0.69</td>
#     </tr>    <tr>
#         <th id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063level0_row1" class="row_heading level0 row1" >stars_github</th>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row1_col0" class="data row1 col0" >0.86</td>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row1_col1" class="data row1 col1" >1.0</td>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row1_col2" class="data row1 col2" >0.77</td>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row1_col3" class="data row1 col3" >0.67</td>
#     </tr>    <tr>
#         <th id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063level0_row2" class="row_heading level0 row2" >pulls_issues</th>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row2_col0" class="data row2 col0" >0.82</td>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row2_col1" class="data row2 col1" >0.77</td>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row2_col2" class="data row2 col2" >1.0</td>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row2_col3" class="data row2 col3" >0.66</td>
#     </tr>    <tr>
#         <th id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063level0_row3" class="row_heading level0 row3" >subscribers</th>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row3_col0" class="data row3 col0" >0.69</td>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row3_col1" class="data row3 col1" >0.67</td>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row3_col2" class="data row3 col2" >0.66</td>
#         <td id="T_d1c88759_104e_11e9_8fb3_5ce0c5eca063row3_col3" class="data row3 col3" >1.0</td>
#     </tr></tbody>
# </table>

# %%
df_tmp=npm.dropna()
df_tmp=df_tmp.loc[:,['downloads','stars_npm','direct_runtime']]
df_tmp.dropna(inplace=True)
for x in df_tmp:
    #if x!= "first_release":
    df_tmp[x]=df_tmp[x].apply(float)
df_tmp.corr(method="pearson").style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row0_col0 {
#             background-color:  #b40426;
#         }    #T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row0_col1 {
#             background-color:  #3b4cc0;
#         }    #T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row0_col2 {
#             background-color:  #7396f5;
#         }    #T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row1_col0 {
#             background-color:  #3b4cc0;
#         }    #T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row1_col1 {
#             background-color:  #b40426;
#         }    #T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row1_col2 {
#             background-color:  #f5c1a9;
#         }    #T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row2_col0 {
#             background-color:  #3b4cc0;
#         }    #T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row2_col1 {
#             background-color:  #ead4c8;
#         }    #T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row2_col2 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_7cd78624_1051_11e9_8fb3_5ce0c5eca063" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >downloads</th>
#         <th class="col_heading level0 col1" >stars_npm</th>
#         <th class="col_heading level0 col2" >direct_runtime</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_7cd78624_1051_11e9_8fb3_5ce0c5eca063level0_row0" class="row_heading level0 row0" >downloads</th>
#         <td id="T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row0_col0" class="data row0 col0" >1.0</td>
#         <td id="T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row0_col1" class="data row0 col1" >0.32</td>
#         <td id="T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row0_col2" class="data row0 col2" >0.44</td>
#     </tr>    <tr>
#         <th id="T_7cd78624_1051_11e9_8fb3_5ce0c5eca063level0_row1" class="row_heading level0 row1" >stars_npm</th>
#         <td id="T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row1_col0" class="data row1 col0" >0.32</td>
#         <td id="T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row1_col1" class="data row1 col1" >1.0</td>
#         <td id="T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row1_col2" class="data row1 col2" >0.75</td>
#     </tr>    <tr>
#         <th id="T_7cd78624_1051_11e9_8fb3_5ce0c5eca063level0_row2" class="row_heading level0 row2" >direct_runtime</th>
#         <td id="T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row2_col0" class="data row2 col0" >0.44</td>
#         <td id="T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row2_col1" class="data row2 col1" >0.75</td>
#         <td id="T_7cd78624_1051_11e9_8fb3_5ce0c5eca063row2_col2" class="data row2 col2" >1.0</td>
#     </tr></tbody>
# </table>

# %%
df_tmp.corr(method="spearman").style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row0_col0 {
#             background-color:  #b40426;
#         }    #T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row0_col1 {
#             background-color:  #3b4cc0;
#         }    #T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row0_col2 {
#             background-color:  #b1cbfc;
#         }    #T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row1_col0 {
#             background-color:  #445acc;
#         }    #T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row1_col1 {
#             background-color:  #b40426;
#         }    #T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row1_col2 {
#             background-color:  #3b4cc0;
#         }    #T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row2_col0 {
#             background-color:  #b9d0f9;
#         }    #T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row2_col1 {
#             background-color:  #3b4cc0;
#         }    #T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row2_col2 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >downloads</th>
#         <th class="col_heading level0 col1" >stars_npm</th>
#         <th class="col_heading level0 col2" >direct_runtime</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063level0_row0" class="row_heading level0 row0" >downloads</th>
#         <td id="T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row0_col0" class="data row0 col0" >1.0</td>
#         <td id="T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row0_col1" class="data row0 col1" >0.53</td>
#         <td id="T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row0_col2" class="data row0 col2" >0.7</td>
#     </tr>    <tr>
#         <th id="T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063level0_row1" class="row_heading level0 row1" >stars_npm</th>
#         <td id="T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row1_col0" class="data row1 col0" >0.53</td>
#         <td id="T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row1_col1" class="data row1 col1" >1.0</td>
#         <td id="T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row1_col2" class="data row1 col2" >0.51</td>
#     </tr>    <tr>
#         <th id="T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063level0_row2" class="row_heading level0 row2" >direct_runtime</th>
#         <td id="T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row2_col0" class="data row2 col0" >0.7</td>
#         <td id="T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row2_col1" class="data row2 col1" >0.51</td>
#         <td id="T_82b41fe4_1051_11e9_8fb3_5ce0c5eca063row2_col2" class="data row2 col2" >1.0</td>
#     </tr></tbody>
# </table>

# %%
#npm['usage']=(npm['dep_pro'] + npm['dep_repo'])
npm['community_interest']=(npm['stars_github']+
                          npm['forks']+
                          (npm['pulls_issues']*npm['pulls_issues'])
                          )

# %%
npm_search=npm.dropna().reset_index()

for x in npm_search:
    if x!= "name":
        npm_search[x]=npm_search[x].apply(float)

# %%
# TOP 1000 DOWNLOADED
top=1000

npm_search.sort_values('downloads', inplace=True, ascending=False)
df_downloads=npm_search.head(top).loc[:,['name']]
df_downloads['type']='downloads'

# TOP 1000 STARRED
npm_search.sort_values('stars_npm', inplace=True, ascending=False)
df_stars=npm_search.head(top).loc[:,['name']]
df_stars['type']='stars npm'

# TOP 1000 SUBSCRIBED
npm_search.sort_values('subscribers', inplace=True, ascending=False)
df_subscribers=npm_search.head(top).loc[:,['name']]
df_subscribers['type']='subscribers'

# TOP 1000 COMMUNITY INTEREST

npm_search.sort_values('community_interest', inplace=True, ascending=False)
df_community=npm_search.head(top).loc[:,['name']]
df_community['type']='community interest'

# TOP 1000 transitive runtime
#npm_search.sort_values('transitive_runtime', inplace=True,ascending=False)
#df_transitive=npm_search.head(top).loc[:,['name']]
#df_transitive['type']='transitive runtime'

# TOP 1000 repo runtime
npm_search.sort_values('repo_runtime', inplace=True, ascending=False)
df_repo=npm_search.head(top).loc[:,['name']]
df_repo['type']='repo runtime'


df_all=pd.concat([df_downloads,df_stars,df_subscribers,df_community,
                  #df_transitive, 
                  df_repo])

# %%
# SEARCH IN NPMJS.COM
npm_search.sort_values('direct_runtime', inplace=True, ascending=False)
df_dependents=npm_search.head(top).loc[:,['name']]
df_dependents['top_dependent']='True'


df_all=df_all.set_index('name').merge(df_dependents.
                                      set_index('name'),
                                      left_index=True,
                                      right_index=True,
                                      how='outer').dropna().reset_index()
df_all.drop(['top_dependent'], axis=1, inplace=True)

# %%
lis=df_all.groupby('name')['type'].apply(list)
tab= [i for i in lis]
from pymining import seqmining 
freq_seqs = seqmining.freq_seq_enum(tab, 1)
#print("Seuls: ",sorted(freq_seqs))

# %% [markdown]
# # Venn diagram with 5 edges

# %%
# Venn diagram with 6 edges
number={}
number['community interest']=10000
number['downloads']=1000
number['stars npm']=100
number['subscribers']=10
number['repo runtime']=1

tabs={}
for x in freq_seqs:
    result=0
    for y in x[0]:
        result=result+number[y]
    result=str("%05d" % (result,))
    tabs[result]=x[1]

# %%
labels = ['00001','00010','00100','01000','10000']
for x in labels:
    print(tabs[x])
# Out:
# 551
# 217
# 604
# 393
# 257

# %%
tabs = {'00001': 551,
 '00010': 217,
 '00011': 138,
 '00100': 604,
 '00101': 392,
 '00110': 195,
 '00111': 132,
 '01000': 393,
 '01001': 341,
 '01010': 77,
 '01011': 71,
 '01100': 240,
 '01101': 217,
 '01110': 74,
 '01111': 69,
 '10000': 257,
 '10001': 157,
 '10010': 191,
 '10011': 126,
 '10100': 228,
 '10101': 149,
 '10110': 175,
 '10111': 120,
 '11000': 95,
 '11001': 85,
 '11010': 71,
 '11011': 65,
 '11100': 90,
 '11101': 81,
 '11110': 68,
 '11111': 63}

# %matplotlib inline
#https://github.com/tctianchi/pyvenn
import venn
plt.rcParams['text.usetex'] = False
font = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 18}
plt.rc('font', **font)

plt.rcParams['text.usetex'] = True

#labels = venn.get_labels([range(10), range(5, 15), range(3, 8), range(8, 17), range(10, 20)], fill=['number', 'logic'])
fig, ax = venn.venn5(tabs, names=list(number.keys()))
ax.legend('')
fig.set_size_inches(8,8)

# %%
# %matplotlib inline
#https://github.com/tctianchi/pyvenn
import venn
plt.rcParams['text.usetex'] = False
font = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 18}
plt.rc('font', **font)

plt.rcParams['text.usetex'] = True

#labels = venn.get_labels([range(10), range(5, 15), range(3, 8), range(8, 17), range(10, 20)], fill=['number', 'logic'])
fig, ax = venn.venn5(tabs, names=list(number.keys()))
ax.legend('')
fig.set_size_inches(8,8)

# %%
freq_seqs
# Out:
# {(('community interest',), 257),
#  (('community interest', 'repo runtime'), 157),
#  (('downloads',), 393),
#  (('downloads', 'community interest'), 95),
#  (('downloads', 'community interest', 'repo runtime'), 85),
#  (('downloads', 'repo runtime'), 341),
#  (('downloads', 'stars npm'), 240),
#  (('downloads', 'stars npm', 'community interest'), 90),
#  (('downloads', 'stars npm', 'community interest', 'repo runtime'), 81),
#  (('downloads', 'stars npm', 'repo runtime'), 217),
#  (('downloads', 'stars npm', 'subscribers'), 74),
#  (('downloads', 'stars npm', 'subscribers', 'community interest'), 68),
#  (('downloads',
#    'stars npm',
#    'subscribers',
#    'community interest',
#    'repo runtime'),
#   63),
#  (('downloads', 'stars npm', 'subscribers', 'repo runtime'), 69),
#  (('downloads', 'subscribers'), 77),
#  (('downloads', 'subscribers', 'community interest'), 71),
#  (('downloads', 'subscribers', 'community interest', 'repo runtime'), 65),
#  (('downloads', 'subscribers', 'repo runtime'), 71),
#  (('repo runtime',), 551),
#  (('stars npm',), 604),
#  (('stars npm', 'community interest'), 228),
#  (('stars npm', 'community interest', 'repo runtime'), 149),
#  (('stars npm', 'repo runtime'), 392),
#  (('stars npm', 'subscribers'), 195),
#  (('stars npm', 'subscribers', 'community interest'), 175),
#  (('stars npm', 'subscribers', 'community interest', 'repo runtime'), 120),
#  (('stars npm', 'subscribers', 'repo runtime'), 132),
#  (('subscribers',), 217),
#  (('subscribers', 'community interest'), 191),
#  (('subscribers', 'community interest', 'repo runtime'), 126),
#  (('subscribers', 'repo runtime'), 138)}

# %% [markdown]
# # Venn diagram with 6 edges

# %%
# Venn diagram with 6 edges
number={}
number['community interest']=100000
number['downloads']=10000
number['stars npm']=1000
number['subscribers']=100
number['transitive runtime']=10
number['repo runtime']=1

tabs={}
for x in freq_seqs:
    result=0
    for y in x[0]:
        result=result+number[y]
    result=str("%06d" % (result,))
    tabs[result]=x[1]

# %%
labels = ['000001','000010','000100','001000','010000','100000']
for x in labels:
    print(tabs[x])
# Out:
# 551
# 462
# 217
# 604
# 394
# 256

# %%
# %matplotlib inline
#https://github.com/tctianchi/pyvenn
import venn
plt.rcParams['text.usetex'] = False
font = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 18}
plt.rc('font', **font)

plt.rcParams['text.usetex'] = True

#labels = venn.get_labels([range(10), range(5, 15), range(3, 8), range(8, 17), range(10, 20)], fill=['number', 'logic'])
fig, ax = venn.venn6(tabs, names=list(sorted(number.keys())))
ax.legend(bbox_to_anchor=(1, 0))
fig.set_size_inches(20,10)

# %%
tabs={'00001': 512,
 '00010': 166,
 '00011': 95,
 '00100': 592,
 '00101': 365,
 '00110': 152,
 '00111': 94,
 '01000': 391,
 '01001': 345,
 '01010': 61,
 '01011': 58,
 '01100': 237,
 '01101': 223,
 '01110': 59,
 '01111': 57,
 '10000': 193,
 '10001': 119,
 '10010': 139,
 '10011': 89,
 '10100': 177,
 '10101': 116,
 '10110': 131,
 '10111': 88,
 '11000': 78,
 '11001': 76,
 '11010': 56,
 '11011': 54,
 '11100': 76,
 '11101': 74,
 '11110': 55,
 '11111': 53}

# %matplotlib inline
#https://github.com/tctianchi/pyvenn
import venn
plt.rcParams['text.usetex'] = False
font = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 18}
plt.rc('font', **font)

plt.rcParams['text.usetex'] = True

#labels = venn.get_labels([range(10), range(5, 15), range(3, 8), range(8, 17), range(10, 20)], fill=['number', 'logic'])
fig, ax = venn.venn5(tabs, names=list(sorted(number.keys())))
ax.legend(bbox_to_anchor=(1, 0))
fig.set_size_inches(6,6)
#ax.figure.savefig('../../../seneca_research/npm_popularity/figures/venn_pop.pdf', bbox_inches='tight', facecolor='white')

# %%
# %matplotlib inline
#https://github.com/tctianchi/pyvenn
import venn

# %%
#Spearmanr R correlation
scipy.stats.spearmanr(npm.dep_repo,
                     npm.dep_repo)
# Out:
# SpearmanrResult(correlation=1.0, pvalue=0.0)

# %%
npm.head(1)
# Out:
#                  url  first_release  dep_pro  dep_repo   downloads  \
# name
# mocha  mochajs-mocha         2348.0   129000  305000.0  74746258.0
#
#        dependents  stars_npm  stars_github   forks  subscribers  pulls_issues  \
# name
# mocha      3956.0      694.0       15080.0  2112.0        399.0        3304.0
#
#        commits     usage  community interest  community_interest
# name
# mocha    311.0  434000.0          10933608.0          10933608.0

# %%
#Pearsonr R correlation
lib=['dep_pro']
scipy.stats.kendalltau(npm.dep_pro,
                     npm.dep_repo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-14916ad227db> in <module>()
#       1 #Pearsonr R correlation
#       2 lib=['dep_pro']
# ----> 3 scipy.stats.kendalltau(npm.dep_pro,
#       4                      npm.dep_repo)
#
# NameError: name 'scipy' is not defined

# %%
df=npm.query('stars_github<123128')
#df['community_interest']=(df['stars_github']+
#                          df['forks']+
#                          (df['pulls_issues']*
#                           df['pulls_issues'])
#                         )
#df=df.query('community_interest<2000000')
#df.sort_values(['community_interest'],ascending=False, inplace=True)
#df['community_interest']=df['community_interest'].apply(lambda x: int(x/100000))

df.sort_values('stars_github', inplace=True)
df['stars_github']=df['stars_github'].apply(lambda x: int(x/1000))

ax = sns.boxplot(x="stars_github", y="pulls_issues", data=df,  color="white", linewidth=1)
ax.figure.set_size_inches(11,3)
for patch in ax.patches:
    patch.set_edgecolor('black')
for x in ax.artists:
    x.set_edgecolor('.2')
ax.legend(loc='upper right', bbox_to_anchor=(1, 1.3), ncol=3, fontsize=20, fancybox=True, shadow=True)

plt.setp(ax.lines, color=".2", mfc='.2', mec='.2')

ax.figure.set_size_inches(12,3)
#ax.set_xlim(0,20)
#ax.set_ylim(0,10000)
#ax.set_yscale('log')
#ax.set_xscale('log')
ax.set_ylabel('stars github ')
ax.set_xlabel('Community interest ')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# Text(0.5,0,'Community interest ')

# %%
librariesio.query('name=="jasmine"')
# Out:
#            name transitive_runtime direct_runtime transitive  direct    repo  \
# 150279  jasmine              515.0            343    52509.0  6347.0  6852.0
#
#        repo_runtime
# 150279       1517.0

# %%
df_tmp.head()
# Out:
#               downloads  dependents  stars_npm  stars_github  forks  \
# name
# gulp-prefix        5031           5          3             7      4
# path-format       20222           6          0             0      0
# corelocation        378           3          0             4      1
# ver-iterator         92           1          0             2      0
# zerorpc           15081          11          7           553    103
#
#               subscribers  pulls_issues transitive_runtime direct_runtime  \
# name
# gulp-prefix             1             9                5.0              7
# path-format             1             0               15.0              7
# corelocation            1             4                3.0              4
# ver-iterator            1            13                2.0              3
# zerorpc                36            96               86.0             90
#
#              transitive direct  repo repo_runtime
# name
# gulp-prefix        17.0   12.0  47.0          6.0
# path-format        27.0    7.0   3.0          3.0
# corelocation        3.0    4.0   1.0          1.0
# ver-iterator        5.0    4.0   1.0          1.0
# zerorpc            86.0   90.0  34.0         34.0

# %%
df_tmp=npm.dropna()

for x in df_tmp:
    df_tmp[x]=df_tmp[x].apply(float)
    df_tmp[x]=df_tmp[x].apply(float)


color_map = plt.cm.Spectral_r
fig=plt.figure(figsize=(10,9))
ax = fig.add_subplot(111)
image = plt.hexbin(data=df_tmp, x='direct_runtime', y='dependents',cmap=color_map,gridsize=1000,mincnt=1,bins='log')
cb = plt.colorbar(image,spacing='uniform',extend='max')
ax.figure.set_size_inches(12,4)
ax.set_xlim(0,10000)
ax.set_ylim(0,10000)
ax.set_ylabel('\# Dependent packages')
ax.set_xlabel('\# Dependent repositories')

#z = np.polyfit(df['downloadsCount'], df['downloadsAcceleration'], 2)
#p = np.poly1d(z)
#plt.plot(df['downloadsCount'],p(df['downloadsCount']),"brown", linestyle='--', linewidth=5)
#ax.figure.savefig('../../../seneca_research/npm_popularity/figures/pro_repo.pdf', bbox_inches='tight', facecolor='white')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Text(0.5,0,'\\# Dependent repositories')

# %%
scipy.stats.pearsonr(df_tmp.direct_runtime,
                     df_tmp.dependents)
# Out:
# (0.99855045972581891, 0.0)

# %%
versions=pd.read_csv('../../jsep2018/csv/versions_npm_march.csv', 
                            sep=';', dtype=object, index_col=None,  error_bad_lines=False)
print(len(versions))
versions.head(2)
# Out:
# 4760450
#   package version        date semver release_type Major Minor Patch
# 0       0   0.0.0  2014-04-01  0.0.0      initial     0     0     0
# 1      0-   0.0.1  2017-03-06  0.0.1      initial     0     0     1

# %%
versions.package.drop_duplicates().size
# Out:
# 698648
