# %%
# %matplotlib inline
import seaborn as sns; sns.set(style="ticks", color_codes=True)
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import gridspec
import scipy
style.use('ggplot')
import datetime
from io import StringIO
import re
import numpy as np
from datetime import datetime
import math
from matplotlib.texmanager import TexManager


sns.set_style('whitegrid')
sns.set_palette('colorblind')
FIG_SIZE = (12, 3)
TexManager.font_info['Times New Roman'] = ('Times New Roman', r'\usepackage{Times New Roman}')

font = {'family' : 'Times New Roman',
        'weight' : 'bold',
        'size'   : 30}
plt.rc('font', **font)
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['text.usetex'] = True

plt.rcParams['xtick.labelsize'] = 22
plt.rcParams['ytick.labelsize'] = 22
plt.rcParams['axes.labelsize']= 22
plt.rcParams['lines.linewidth']= 2
plt.rcParams['lines.markersize']= 2

# %%
# Already prepared the data for the NPM_FINAL dataframe
#Filter: at least 700 days, github, 
npm_packages=pd.read_csv('../../popularity/csv/npm_popularity_2yearsOld.csv', sep=';', dtype=object, index_col='name')

npm_packages['first_release']=npm_packages['first_release'].apply(lambda x:
                                                                  float("".join(re.findall("[0-9.]+", x))) if 'day' in x 
                                                                  else float("".join(re.findall("[0-9.]+", x)))*30 if 'month' in x
                                                                  else (datetime.now().date() - 
                                                                        datetime.strptime(x, '%b %d, %Y').date()).days)

for x in npm_packages:
    #if x!= "first_release":
    npm_packages[x]=npm_packages[x].apply(float)
    npm_packages[x]=npm_packages[x].apply(int)
        

npm_packages.drop_duplicates(inplace=True)
npm_packages.drop('contributors', axis=1, inplace=True)

npm2=pd.read_csv('../../popularity/csv/only_npm.csv', sep=',', dtype=object, index_col=None)
npm2=npm2.loc[:,['Name','Repository URL']]
npm2=npm2.rename(columns = {'Name':'name','Repository URL':'url'})

npm2=npm2.set_index('name').merge(npm_packages,
                               left_index=True, 
                               right_index=True,
                               how='outer').dropna().reset_index()
npm2.dropna(inplace=True)

# %%
# remove duplicates, take only the popular ones with unique repository name
npm=npm2.sort_values('downloads', ascending=False)
npm['url']=npm['url'].apply(lambda x: x.split('/')[-2]+'-'+x.split('/')[-1])
npm=npm.groupby('url').first().reset_index()
npm.set_index('name', inplace=True)
len(npm)
# Out:
# 175774

# %%
len(npm.query('stars_npm==0'))/len(npm)
# Out:
# 0.7625644293240184

# %%
df=npm.sort_values('dependents', ascending=False)
df=df.head(30)
df['repo usage']=df['dependents']
ax=df.plot(kind='bar', color=['brown'], y='repo usage', width=0.9)
ax.set_ylabel('Usage ')
ax.set_xlabel(' Packages')
ax.legend( loc='upper right', 
          bbox_to_anchor=(1, 1.2), fontsize=19,ncol=3, fancybox=True, shadow=True)
plt.xticks(rotation='80')
#ax.set_yscale('log')
ax.figure.set_size_inches(12,3)

# %%
f=list(df.index)+list(df2.index)
len(set(f))
# Out:
# 55

# %%
df2=npm.sort_values('stars_github', ascending=False)
df2=df2.loc[:,['stars_github']]
df2.drop_duplicates(inplace=True)
df2=df2.sort_values('stars_github', ascending=False)
df2=df2.head(30)

df2['repo usage']=df2['stars_github']
ax=df2.plot(kind='bar', color=['brown'], y='repo usage', width=0.9)
ax.set_ylabel('Usage ')
ax.set_xlabel(' Packages')
ax.legend( loc='upper right', 
          bbox_to_anchor=(1, 1.2), fontsize=19,ncol=3, fancybox=True, shadow=True)
plt.xticks(rotation='80')
#ax.set_yscale('log')
ax.figure.set_size_inches(12,3)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df=npm.sort_values(['dep_pro'],ascending=False)
df.query('dep_pro<18000', inplace=True)
df.sort_values('dep_pro', inplace=True)
df['dep_pro']=df['dep_pro'].apply(lambda x: str(int(x/1000))+'k')


ax = sns.boxplot(x="dep_pro", y="dep_repo", data=df,  color="orange", linewidth=1)
ax.figure.set_size_inches(11,3)
for patch in ax.patches:
    patch.set_edgecolor('black')
for x in ax.artists:
    x.set_edgecolor('.2')
ax.legend(loc='upper right', bbox_to_anchor=(1, 1.3), ncol=3, fontsize=20, fancybox=True, shadow=True)
plt.setp(ax.lines, color=".2", mfc='.2', mec='.2')

ax.figure.set_size_inches(12,3)
#ax.set_xlim(0,50)
ax.set_ylim(0,180000)
#ax.set_yscale('log')
#ax.set_xscale('log')
ax.set_xlabel('\# transitive dependent packages')
ax.set_ylabel('\# dependent repostiries')
ax.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

ax.figure.savefig('../../../seneca_research/npm_popularity/figures/dep_pro_repo.pdf', bbox_inches='tight', facecolor='white')
#color_map = plt.cm.Spectral_r
#fig=plt.figure(figsize=(10,9))
#ax = fig.add_subplot(111)
#image = plt.hexbin(data=df, x='dep_pro', y='dep_repo',cmap=color_map,gridsize=500,mincnt=1,bins='log')
#cb = plt.colorbar(image,spacing='uniform',extend='max')

#z = np.polyfit(df['downloadsCount'], df['downloadsAcceleration'], 2)
#p = np.poly1d(z)
#plt.plot(df['downloadsCount'],p(df['downloadsCount']),"brown", linestyle='--', linewidth=5)

# %%
#Pearsonr R correlation
scipy.stats.pearsonr(npm.dep_pro,
                     npm.dep_repo)
# Out:
# (0.64730190933695653, 0.0)

# %%
#Spearmanr R correlation
scipy.stats.spearmanr(npm.dep_pro,
                     npm.dep_repo)
# Out:
# SpearmanrResult(correlation=0.61039054550390193, pvalue=0.0)

# %%
if False:
    df=npm_packages.sort_values(['dep_pro'],ascending=False)
    df.query('dep_pro<15000', inplace=True)
    df.sort_values('dep_pro', inplace=True)

    color_map = plt.cm.Spectral_r
    fig=plt.figure(figsize=(10,9))
    ax = fig.add_subplot(111)
    image = plt.hexbin(data=df, x='dep_pro', y='dep_repo',cmap=color_map,gridsize=500,mincnt=1,bins='log')
    cb = plt.colorbar(image,spacing='uniform',extend='max')
    ax.set_xlim(0,2000)
    ax.set_ylim(0,100000)
    ax.figure.set_size_inches(12,3)

# %%
for x in npm:
    if x!= "name" and x!= "url":
        npm[x]=npm[x].apply(float)
        npm[x]=npm[x].apply(int)

# %%
# TOP 1000 DOWNLOADED
npm.reset_index(inplace=True)
top=1000
npm.sort_values('downloads', inplace=True, ascending=False)
df_downloads=npm.head(top).loc[:,['name']]
df_downloads['type']='downloads'

# TOP 1000 STARRED
npm.sort_values('stars_npm', inplace=True, ascending=False)
df_stars=npm.head(top).loc[:,['name']]
df_stars['type']='stars npm'

# TOP 1000 SUBSCRIBED
npm.sort_values('subscribers', inplace=True, ascending=False)
df_subscribers=npm.head(top).loc[:,['name']]
df_subscribers['type']='subscribers'

# TOP 1000 COMMUNITY INTEREST
df_community=npm.sort_values('forks', ascending=False)
df_community['community interest']=(df_community['stars_github']+
                          df_community['forks']+
                          (df_community['pulls_issues']*
                           df_community['pulls_issues'])
                         )
df_community.sort_values('community interest', inplace=True, ascending=False)
df_community=df_community.head(top).loc[:,['name']]
df_community['type']='community interest'

# TOP 1000 USED
df_usage=npm.sort_values('forks', ascending=False)
df_usage['usage']=(df_usage['dep_pro'] + df_usage['dep_repo'])
df_usage.sort_values('usage', inplace=True, ascending=False)
df_usage=df_usage.head(top).loc[:,['name']]
df_usage['type']='usage'

df_all=pd.concat([df_downloads,df_stars,df_subscribers,df_community,df_usage])

# %%
npm.sort_values('dependents', inplace=True, ascending=False)
df_dependents=npm.head(top).loc[:,['name']]
df_dependents['top_dependent']='True'


df_all=df_all.set_index('name').merge(df_dependents.
                                      set_index('name'),
                                      left_index=True,
                                      right_index=True,
                                      how='outer').dropna().reset_index()
df_all.drop(['top_dependent'], axis=1, inplace=True)

# %%
lis=df_all.groupby('name')['type'].apply(list)
tab= [i for i in lis]
from pymining import seqmining 
freq_seqs = seqmining.freq_seq_enum(tab, 1)
#print("Seuls: ",sorted(freq_seqs))

# %%
number={'community interest': 10000,
 'downloads': 1000,
 'stars npm': 100,
 'subscribers': 10,
 'usage': 1}

# %%
tabs={'00001': 512,
 '00010': 166,
 '00011': 95,
 '00100': 592,
 '00101': 365,
 '00110': 152,
 '00111': 94,
 '01000': 391,
 '01001': 345,
 '01010': 61,
 '01011': 58,
 '01100': 237,
 '01101': 223,
 '01110': 59,
 '01111': 57,
 '10000': 193,
 '10001': 119,
 '10010': 139,
 '10011': 89,
 '10100': 177,
 '10101': 116,
 '10110': 131,
 '10111': 88,
 '11000': 78,
 '11001': 76,
 '11010': 56,
 '11011': 54,
 '11100': 76,
 '11101': 74,
 '11110': 55,
 '11111': 53}

# %%
number={}
number['community interest']=10000
number['downloads']=1000
number['stars npm']=100
number['subscribers']=10
number['usage']=1
tabs={}
for x in freq_seqs:
    result=0
    for y in x[0]:
        result=result+number[y]
    result=str("%05d" % (result,))
    tabs[result]=x[1]

# %%
# %matplotlib inline
#https://github.com/tctianchi/pyvenn
import venn
plt.rcParams['text.usetex'] = False
font = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 18}
plt.rc('font', **font)

plt.rcParams['text.usetex'] = True

#labels = venn.get_labels([range(10), range(5, 15), range(3, 8), range(8, 17), range(10, 20)], fill=['number', 'logic'])
fig, ax = venn.venn5(tabs, names=list(sorted(number.keys())))
ax.legend(bbox_to_anchor=(1, 0))
fig.set_size_inches(6,6)
ax.figure.savefig('../../../seneca_research/npm_popularity/figures/venn_pop.pdf', bbox_inches='tight', facecolor='white')

# %%
# %matplotlib inline
#https://github.com/tctianchi/pyvenn
import venn

# %%
#Spearmanr R correlation
scipy.stats.spearmanr(npm.dependents,
                     npm.downloads)
# Out:
# SpearmanrResult(correlation=0.53284272527678, pvalue=0.0)

# %%
#Pearsonr R correlation
scipy.stats.kendalltau(npm.stars_npm,
                     npm.dependents)
# Out:
# KendalltauResult(correlation=0.27726603397109878, pvalue=0.0)

# %%
df=npm.query('stars_github<123128')
#df['community_interest']=(df['stars_github']+
#                          df['forks']+
#                          (df['pulls_issues']*
#                           df['pulls_issues'])
#                         )
#df=df.query('community_interest<2000000')
#df.sort_values(['community_interest'],ascending=False, inplace=True)
#df['community_interest']=df['community_interest'].apply(lambda x: int(x/100000))

df.sort_values('stars_github', inplace=True)
df['stars_github']=df['stars_github'].apply(lambda x: int(x/1000))

ax = sns.boxplot(x="stars_github", y="pulls_issues", data=df,  color="white", linewidth=1)
ax.figure.set_size_inches(11,3)
for patch in ax.patches:
    patch.set_edgecolor('black')
for x in ax.artists:
    x.set_edgecolor('.2')
ax.legend(loc='upper right', bbox_to_anchor=(1, 1.3), ncol=3, fontsize=20, fancybox=True, shadow=True)

plt.setp(ax.lines, color=".2", mfc='.2', mec='.2')

ax.figure.set_size_inches(12,3)
#ax.set_xlim(0,20)
#ax.set_ylim(0,10000)
#ax.set_yscale('log')
#ax.set_xscale('log')
ax.set_ylabel('stars github ')
ax.set_xlabel('Community interest ')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# Text(0.5,0,'Community interest ')

# %%
npm_packages.query('stars_npm>10')
# Out:
#                                first_release  dep_pro  dep_repo  downloads  \
# name
# Faker                                   2053       26       238     142944
# a11y                                    1275       14        51      53218
# abbrev                                  2576      173     92900  179396325
# accepts                                 1564      314     92400  218480709
# accessibility-developer-tools           1210       24       823    3058726
# accounting                              2362      100       451    2895006
# acl                                     2428       64      1120     343213
# acorn                                   2023      907    101000  393893493
# actionhero                              1541       20       109      69475
# activedirectory                         1667       23        83     373009
# adm-zip                                 2237      877     12100   53887269
# adventure                               1379       59       104      13625
# after                                   2314      363     30900   67889792
# agenda                                  1623       49       416     543646
# agenda-ui                               1409        4        33      20932
# aglio                                   1606       33       126     230296
# airsonos                                1479        0         2      16937
# aliasify                                1563      143       585    3368684
# aliyun-sdk                              1521       63       162      79217
# amazon-product-api                      1562        6        59      43029
# amd-optimize                            1487       33       256      59112
# amqp                                    2510      299       906     896510
# amqplib                                 1753      672      1400    6384172
# angular-cli                             1276      442      8370    1032656
# angular-translate                       1313      117       873    2791874
# angular-ui-router                       1571      479      7960   10297648
# animate.css                             1406      204      2220    1875561
# ansi                                    2265      226      4680   16522532
# ansi-styles                             1713      236    115000  394957249
# any-promise                             1250      246      8260   31561641
# ...                                      ...      ...       ...        ...
# angular2-datatable                       750       15       226     268556
# axios-mock-adapter                       747       84       388    1812627
# codelyzer                                746     2760     29600   13383570
# botbuilder                               740       92      1320     401481
# popper.js                                739      166       958    7946333
# autocannon                               739       12        21      49698
# apollo-client                            738      148      1470    5413122
# mocha-typescript                         734      174       199     284341
# react-navigation                         734       56      2320    2278928
# graphql-tools                            731      174       990    2888976
# standard-version                         731     1240      1800     759824
# scripty                                  730       22        32      69033
# react-pdf-js                             726        4        18     182603
# brain.js                                 724        3        11      17226
# telegraf                                 724       27       110      77549
# weex-toolkit                             722        4         3      64839
# express-acl                              721        0         3      13702
# bootstrap-v4-dev                         721        2        10       7550
# react-apollo                             720       74       962    3257806
# favicons-webpack-plugin                  720       64       413     749933
# typeorm                                  720       39       106     439221
# eslint-config-airbnb-base                720     5300     14900   29644950
# dom-to-image                             716       14        36     282659
# homebridge-server                        714        0         1      13446
# scrape-it                                711       30        95      21668
# react-redux-loading-bar                  710        4       194     355822
# shx                                      706      516      3410     577557
# toobusy-js                              1543       49       220     597863
# technicalindicators                      704        0         7      22950
# lodash-webpack-plugin                    703      256       457    1383084
#
#                                dependents  stars_npm  stars_github  forks  \
# name
# Faker                                  24         40           214     26
# a11y                                    9         15          1466     80
# abbrev                                146         15           122     18
# accepts                               314         20           140     15
# accessibility-developer-tools          21         12          1729    263
# accounting                            106         24          3781    419
# acl                                    49         60          1871    297
# acorn                                 669         33          3339    339
# actionhero                              6         13          1816    208
# activedirectory                        25         22           379    112
# adm-zip                               641         46           664    201
# adventure                              56         14            99     15
# after                                 115         32           107     13
# agenda                                 44        106          3902    437
# agenda-ui                               0         34           268     27
# aglio                                  22         11          3675    381
# airsonos                                0         13          2008    275
# aliasify                               52         12           193     27
# aliyun-sdk                             59         14           549    142
# amazon-product-api                      6         21           284     94
# amd-optimize                           10         14           165     30
# amqp                                  242         44          1594    368
# amqplib                               690         64          1597    252
# angular-cli                             6         55         16562   3613
# angular-translate                      82         13          4361    745
# angular-ui-router                     267         35         13794   3351
# animate.css                           179         40         50175  10822
# ansi                                  160         13           288     30
# ansi-styles                           213         11           184     34
# any-promise                           192         11           157      9
# ...                                   ...        ...           ...    ...
# angular2-datatable                     18         11           194    131
# axios-mock-adapter                     15         15           692     69
# codelyzer                              78         14          1607    152
# botbuilder                            121         18          4989   1977
# popper.js                             410         22          8312    495
# autocannon                              5         20           921     62
# apollo-client                         181         13          6548    690
# mocha-typescript                       14         12           118     20
# react-navigation                      116         15         10888   2384
# graphql-tools                         288         20          1723    213
# standard-version                       55         12          1112    111
# scripty                                 0         24           532     15
# react-pdf-js                            6         12           187     62
# brain.js                                7         15          4558    322
# telegraf                               25         13          1108    160
# weex-toolkit                            0         12           350     71
# express-acl                             0         11           108     25
# bootstrap-v4-dev                        0         11        122996  58436
# react-apollo                          145         16          2680    351
# favicons-webpack-plugin                36         16           584     96
# typeorm                                81         13          5334    567
# eslint-config-airbnb-base             456         57         68304  13041
# dom-to-image                           28         11          3278    393
# homebridge-server                       0         23           130     20
# scrape-it                              30         15          2960    149
# react-redux-loading-bar                 6         12           568     61
# shx                                    25         17           451     18
# toobusy-js                             42         17           240     22
# technicalindicators                     2         13           374     89
# lodash-webpack-plugin                  75         25           707     29
#
#                                subscribers  pulls_issues  commits
# name
# Faker                                    6            21        0
# a11y                                    52            75        2
# abbrev                                   8            16        2
# accepts                                 12            15       21
# accessibility-developer-tools          191           352        1
# accounting                             114           192        0
# acl                                     75           263        3
# acorn                                  107           690      137
# actionhero                              90          1201      392
# activedirectory                         22           189        0
# adm-zip                                 32           206        3
# adventure                                7            14        0
# after                                    4            12        1
# agenda                                 118           587       72
# agenda-ui                               11            24        1
# aglio                                  118           351        1
# airsonos                               151           394        0
# aliasify                                 9            50        0
# aliyun-sdk                              50           150       61
# amazon-product-api                      18           112        4
# amd-optimize                            14            75        0
# amqp                                    67           465        1
# amqplib                                 61           412        9
# angular-cli                           1153         10068      892
# angular-translate                      165          1834       38
# angular-ui-router                      592          3674      204
# animate.css                           2307           799       32
# ansi                                     8            27        1
# ansi-styles                             10            46       11
# any-promise                              6            28        0
# ...                                    ...           ...      ...
# angular2-datatable                      17           152        0
# axios-mock-adapter                      18           128       43
# codelyzer                               60           552      249
# botbuilder                             462          4414      270
# popper.js                              175           599      299
# autocannon                              31           126       33
# apollo-client                          232          3216     1084
# mocha-typescript                         3            61       52
# react-navigation                       305          3920      600
# graphql-tools                           66           709      378
# standard-version                        34           237       17
# scripty                                 23            53        2
# react-pdf-js                            11            67       54
# brain.js                               182           185      130
# telegraf                                46           389      211
# weex-toolkit                            30           350       62
# express-acl                              9            95       24
# bootstrap-v4-dev                      7300         25654     1510
# react-apollo                            91          1909      602
# favicons-webpack-plugin                  7           113        5
# typeorm                                182          1862     1016
# eslint-config-airbnb-base             3027          1763      216
# dom-to-image                            81           204        7
# homebridge-server                       21            58        3
# scrape-it                               46           100       34
# react-redux-loading-bar                 12            61       35
# shx                                     15           127        4
# toobusy-js                              16            19        4
# technicalindicators                     31           122       82
# lodash-webpack-plugin                   16           146       13
#
# [2581 rows x 11 columns]

# %%
df=npm_packages.query('dep_repo>2000')


#df.query('dep_pro<15000', inplace=True)
#df.sort_values('dep_pro', inplace=True)
#df['dep_pro']=df['dep_pro'].apply(lambda x: str(int(x/1000))+'k')


color_map = plt.cm.Spectral_r
fig=plt.figure(figsize=(10,9))
ax = fig.add_subplot(111)
image = plt.hexbin(data=df, x='stars_github', y='stars_npm',cmap=color_map,gridsize=500,mincnt=1,bins='log')
cb = plt.colorbar(image,spacing='uniform',extend='max')
ax.figure.set_size_inches(12,3)
ax.set_xlim(0,20000)
ax.set_ylim(0,500)
ax.set_ylabel('# contributors')
ax.set_xlabel('package lifetime in days')

#z = np.polyfit(df['downloadsCount'], df['downloadsAcceleration'], 2)
#p = np.poly1d(z)
#plt.plot(df['downloadsCount'],p(df['downloadsCount']),"brown", linestyle='--', linewidth=5)
# Out:
# Text(0.5,0,'package lifetime in days')

# %%
df.query('contributors=="100"')
# Out:
#                                                     first_release  dep_pro  \
# name
# express                                                      2658    30300
# mocha                                                        2344   129000
# gulp                                                         1740    43500
# lodash                                                       2177    52400
# babel-core                                                   1149    45900
# webpack                                                      2220    38800
# babel-preset-es2015                                           893    57100
# async                                                        2668    25000
# chai                                                         2315    70900
# eslint                                                       1740    64300
# request                                                      2634    30500
# karma                                                        1857    18100
# babel-preset-react                                            893    20700
# jquery                                                       2578    11400
# commander                                                    2430    18700
# babel-runtime                                                1149    12300
# bluebird                                                     1658    18100
# babel-register                                                880    15300
# webpack-dev-server                                           2029    15200
# mongoose                                                     2667     4290
# underscore                                                   2315    19300
# uglify-js                                                    2651    12300
# autoprefixer                                                 1826     7480
# sinon                                                        2667    29500
# browserify                                                   2622    19900
# jade                                                         2668     4470
# moment                                                       2316    13800
# babel-code-frame                                              893      186
# socket.io                                                    2663     4810
# eslint-plugin-react                                          1210    20400
# ...                                                           ...      ...
# karma-global-dfp                                             1253        0
# cucumber-redbox                                               900        0
# protractor-redbox                                             900        0
# openlayers-test                                              1206        2
# rx-lite-extras-compat                                        1125        0
# rx-core-binding                                               980        1
# rx-core-testing                                               980        0
# podpea-javascript-style                                       985        1
# bmc                                                          1120        0
# oz-style                                                      985        2
# jaws-cli                                                      974        1
# superagent-clone-for-webworker                                974        1
# skyline-sequelize                                             977        0
# less-vars                                                     941        0
# ui-select-that-was-forked-solely-to-update-npm-...            941        1
# superagent-webpack-client                                     941        1
# nkbits-material-ui                                            936        2
# three.js-amd                                                  955        3
# angular2-webpack-starter                                      953        1
# casperjs-semver                                               947        0
# fiziico-test                                                  945        1
# nuclide-process-output-store                                  947        4
# nuclide-process-output                                        947        3
# nuclide-process-output-handler                                947        3
# nuclide-service-parser                                        952        5
# node-expresso                                                1517        1
# nd-node-sass                                                  949        1
# stylus-fixed                                                  949        1
# suberagent                                                    951        0
# eslint-config-liam                                            951        0
#
#                                                     dep_repo  downloads  \
# name
# express                                               468000  193117066
# mocha                                                 305000   74746258
# gulp                                                  302000   39562145
# lodash                                                257000  582034898
# babel-core                                            232000  126999667
# webpack                                               194000  113171034
# babel-preset-es2015                                   194000   58580269
# async                                                 186000  606485217
# chai                                                  185000   61492318
# eslint                                                174000  110405080
# request                                               164000  365557637
# karma                                                 153000   41337369
# babel-preset-react                                    114000   50713631
# jquery                                                112000   54999911
# commander                                             110000  418925804
# babel-runtime                                         105000  166257876
# bluebird                                              105000  218198083
# babel-register                                        102000   98143212
# webpack-dev-server                                     97100   61278192
# mongoose                                               94200   16405012
# underscore                                             92400  171575497
# uglify-js                                              91000  294237510
# autoprefixer                                           88000  115432420
# sinon                                                  87400   45964761
# browserify                                             85700   32161944
# jade                                                   85600   34108139
# moment                                                 83700  149704741
# babel-code-frame                                       83600  143508868
# socket.io                                              80900   74046921
# eslint-plugin-react                                    79000   55472937
# ...                                                      ...        ...
# karma-global-dfp                                           0        106
# cucumber-redbox                                            0        197
# protractor-redbox                                          0        168
# openlayers-test                                            0        175
# rx-lite-extras-compat                                      0       1705
# rx-core-binding                                            0        963
# rx-core-testing                                            0        984
# podpea-javascript-style                                    0        231
# bmc                                                        0        242
# oz-style                                                   0        459
# jaws-cli                                                   0        103
# superagent-clone-for-webworker                             0         92
# skyline-sequelize                                          0       1595
# less-vars                                                  0        104
# ui-select-that-was-forked-solely-to-update-npm-...         0         94
# superagent-webpack-client                                  0        113
# nkbits-material-ui                                         0        244
# three.js-amd                                               0        213
# angular2-webpack-starter                                   0        530
# casperjs-semver                                            0        123
# fiziico-test                                               0        374
# nuclide-process-output-store                               0        387
# nuclide-process-output                                     0        389
# nuclide-process-output-handler                             0        402
# nuclide-service-parser                                     0        710
# node-expresso                                              0        768
# nd-node-sass                                               0        179
# stylus-fixed                                               0         98
# suberagent                                                 0         94
# eslint-config-liam                                         0        795
#
#                                                     dependents  stars_npm  \
# name
# express                                                  19694       2530
# mocha                                                     3956        694
# gulp                                                      5051       1420
# lodash                                                   48782       1458
# babel-core                                                6942        149
# webpack                                                   6783        540
# babel-preset-es2015                                       4509         86
# async                                                    19718       1212
# chai                                                      3222        313
# eslint                                                    4000        321
# request                                                  27117       1496
# karma                                                      670        426
# babel-preset-react                                        3003         71
# jquery                                                    7757        360
# commander                                                20085       1004
# babel-runtime                                             8840         22
# bluebird                                                 15299        595
# babel-register                                            1430         39
# webpack-dev-server                                        2823        129
# mongoose                                                  3231        734
# underscore                                               15215        572
# uglify-js                                                 2796        268
# autoprefixer                                              2984        211
# sinon                                                     1015        187
# browserify                                                2185        928
# jade                                                      2712        298
# moment                                                   13497       1021
# babel-code-frame                                           182          5
# socket.io                                                 4116        792
# eslint-plugin-react                                       2886         93
# ...                                                        ...        ...
# karma-global-dfp                                             0          0
# cucumber-redbox                                              0          0
# protractor-redbox                                            0          0
# openlayers-test                                              0          0
# rx-lite-extras-compat                                        0          0
# rx-core-binding                                              0          0
# rx-core-testing                                              0          0
# podpea-javascript-style                                      0          0
# bmc                                                          0          0
# oz-style                                                     1          0
# jaws-cli                                                     0          0
# superagent-clone-for-webworker                               0          0
# skyline-sequelize                                            0          0
# less-vars                                                    0          0
# ui-select-that-was-forked-solely-to-update-npm-...           0          0
# superagent-webpack-client                                    0          0
# nkbits-material-ui                                           0          0
# three.js-amd                                                 0          0
# angular2-webpack-starter                                     0          3
# casperjs-semver                                              0          0
# fiziico-test                                                 0          0
# nuclide-process-output-store                                 1          0
# nuclide-process-output                                       1          0
# nuclide-process-output-handler                               1          0
# nuclide-service-parser                                       2          0
# node-expresso                                                0          0
# nd-node-sass                                                 0          1
# stylus-fixed                                                 0          0
# suberagent                                                   0          0
# eslint-config-liam                                           0          0
#
#                                                     stars_github  forks  \
# name
# express                                                    37516   6685
# mocha                                                      15080   2112
# gulp                                                       29133   4254
# lodash                                                     30852   3237
# babel-core                                                 26892   2603
# webpack                                                    39454   4918
# babel-preset-es2015                                        26757   2587
# async                                                      23629   2179
# chai                                                        5237    486
# eslint                                                     10970   1903
# request                                                    19073   2270
# karma                                                       9577   1471
# babel-preset-react                                         26755   2587
# jquery                                                     48526  15232
# commander                                                  10633    839
# babel-runtime                                              26670   2575
# bluebird                                                   16521   2069
# babel-register                                             26753   2586
# webpack-dev-server                                          3546    677
# mongoose                                                   15321   2313
# underscore                                                 22652   5124
# uglify-js                                                   8437    911
# autoprefixer                                               15013    867
# sinon                                                       5649    619
# browserify                                                 11856   1044
# jade                                                       16373   1820
# moment                                                     36203   5401
# babel-code-frame                                           26728   2586
# socket.io                                                  40288   7589
# eslint-plugin-react                                         3871    979
# ...                                                          ...    ...
# karma-global-dfp                                            9572   1471
# cucumber-redbox                                             2999    627
# protractor-redbox                                           7432   1943
# openlayers-test                                             3428   1531
# rx-lite-extras-compat                                      18876   2182
# rx-core-binding                                            18876   2182
# rx-core-testing                                            18876   2182
# podpea-javascript-style                                        0      0
# bmc                                                            0      0
# oz-style                                                       0      0
# jaws-cli                                                   22706   2408
# superagent-clone-for-webworker                             12521   1103
# skyline-sequelize                                              0      0
# less-vars                                                      0      0
# ui-select-that-was-forked-solely-to-update-npm-...          3202   1874
# superagent-webpack-client                                  12521   1103
# nkbits-material-ui                                         34624   6347
# three.js-amd                                               40438  15067
# angular2-webpack-starter                                    9632   5386
# casperjs-semver                                             7134   1043
# fiziico-test                                                   0      0
# nuclide-process-output-store                                7571    654
# nuclide-process-output                                      7567    653
# nuclide-process-output-handler                              7569    653
# nuclide-service-parser                                      7567    653
# node-expresso                                                  1      0
# nd-node-sass                                                   1      0
# stylus-fixed                                                9003   1023
# suberagent                                                 12518   1102
# eslint-config-liam                                             0      0
#
#                                                     subscribers  pulls_issues  \
# name
# express                                                    1801          3610
# mocha                                                       399          3304
# gulp                                                       1216          2141
# lodash                                                      800          3735
# babel-core                                                  793          7666
# webpack                                                    1454          6937
# babel-preset-es2015                                         787          7630
# async                                                       722          1522
# chai                                                        128          1150
# eslint                                                      276         10136
# request                                                     439          2904
# karma                                                       354          2966
# babel-preset-react                                          787          7630
# jquery                                                     3549          3988
# commander                                                   206           781
# babel-runtime                                               787          7617
# bluebird                                                    384          1508
# babel-register                                              787          7630
# webpack-dev-server                                           94          1357
# mongoose                                                    566          6310
# underscore                                                  914          2728
# uglify-js                                                   283          3059
# autoprefixer                                                401          1013
# sinon                                                        92          1760
# browserify                                                  321          1820
# jade                                                        589          2993
# moment                                                      955          4518
# babel-code-frame                                            788          7627
# socket.io                                                  1643          3203
# eslint-plugin-react                                          62          1758
# ...                                                         ...           ...
# karma-global-dfp                                            353          2966
# cucumber-redbox                                             188          1059
# protractor-redbox                                           520          4759
# openlayers-test                                             368          8047
# rx-lite-extras-compat                                       607          1507
# rx-core-binding                                             607          1507
# rx-core-testing                                             607          1507
# podpea-javascript-style                                       2             0
# bmc                                                           4             0
# oz-style                                                      8             0
# jaws-cli                                                    872          4871
# superagent-clone-for-webworker                              246          1361
# skyline-sequelize                                             1             1
# less-vars                                                     3             0
# ui-select-that-was-forked-solely-to-update-npm-...          167          2124
# superagent-webpack-client                                   246          1362
# nkbits-material-ui                                         1222         10904
# three.js-amd                                               2261         13699
# angular2-webpack-starter                                    618          2002
# casperjs-semver                                             291          1920
# fiziico-test                                                  1             0
# nuclide-process-output-store                                316          1457
# nuclide-process-output                                      316          1456
# nuclide-process-output-handler                              316          1456
# nuclide-service-parser                                      316          1456
# node-expresso                                                 2             0
# nd-node-sass                                                  1             0
# stylus-fixed                                                376          2370
# suberagent                                                  246          1361
# eslint-config-liam                                            1             0
#
#                                                     contributors  commits
# name
# express                                                      100      116
# mocha                                                        100      311
# gulp                                                         100       38
# lodash                                                       100       82
# babel-core                                                   100     1537
# webpack                                                      100     1413
# babel-preset-es2015                                          100     1607
# async                                                        100       89
# chai                                                         100       76
# eslint                                                       100      648
# request                                                      100       22
# karma                                                        100       81
# babel-preset-react                                           100     1607
# jquery                                                       100       99
# commander                                                    100       58
# babel-runtime                                                100     1595
# bluebird                                                     100       29
# babel-register                                               100     1607
# webpack-dev-server                                           100      154
# mongoose                                                     100     1229
# underscore                                                   100        8
# uglify-js                                                    100      556
# autoprefixer                                                 100      218
# sinon                                                        100      484
# browserify                                                   100       57
# jade                                                         100       46
# moment                                                       100      155
# babel-code-frame                                             100     1605
# socket.io                                                    100       42
# eslint-plugin-react                                          100      614
# ...                                                          ...      ...
# karma-global-dfp                                             100       81
# cucumber-redbox                                              100      136
# protractor-redbox                                            100       76
# openlayers-test                                              100     1624
# rx-lite-extras-compat                                        100        4
# rx-core-binding                                              100        4
# rx-core-testing                                              100        4
# podpea-javascript-style                                      100        0
# bmc                                                          100        0
# oz-style                                                     100        0
# jaws-cli                                                     100     1706
# superagent-clone-for-webworker                               100       87
# skyline-sequelize                                            100        0
# less-vars                                                    100        0
# ui-select-that-was-forked-solely-to-update-npm-...           100       31
# superagent-webpack-client                                    100       87
# nkbits-material-ui                                           100     1905
# three.js-amd                                                 100     3013
# angular2-webpack-starter                                     100      144
# casperjs-semver                                              100       18
# fiziico-test                                                 100        0
# nuclide-process-output-store                                 100     3576
# nuclide-process-output                                       100     3573
# nuclide-process-output-handler                               100     3573
# nuclide-service-parser                                       100     3573
# node-expresso                                                100        0
# nd-node-sass                                                 100        0
# stylus-fixed                                                 100       12
# suberagent                                                   100       87
# eslint-config-liam                                           100        0
#
# [1332 rows x 12 columns]
