# %%
# %matplotlib inline
import seaborn as sns; sns.set(style="ticks", color_codes=True)
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import gridspec
import scipy
style.use('ggplot')
import datetime
from io import StringIO
import re
import numpy as np
from datetime import datetime
import mysql.connector as sql

sns.set_style('whitegrid')
sns.set_palette('colorblind')
FIG_SIZE = (12, 3)
font = {'family' : 'Times New Roman',
        'weight' : 'bold',
        'size'   : 30}
plt.rc('font', **font)
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['text.usetex'] = True

plt.rcParams['xtick.labelsize'] = 22
plt.rcParams['ytick.labelsize'] = 22
plt.rcParams['axes.labelsize']= 22
plt.rcParams['lines.linewidth']= 2
plt.rcParams['lines.markersize']= 2
# Out:
# -----------------------------------------------------------------------
# ImportError                           Traceback (most recent call last)
# <ipython-input-4-f3694b50e12a> in <module>()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 import seaborn as sns; sns.set(style="ticks", color_codes=True)
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#       5 from matplotlib import style
#
# ImportError: No module named 'seaborn'

# %%
# !pip3 install seaborn
# Out:
# The directory '/home/neglectos/.cache/pip/http' or its parent directory is not owned by the current user and the cache has been disabled. Please check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# The directory '/home/neglectos/.cache/pip' or its parent directory is not owned by the current user and caching wheels has been disabled. check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# ...
#     100% |████████████████████████████████| 184kB 634kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 49.6MB 28kB/s eta 0:00:012 0% |▎                               | 389kB 1.1MB/s eta 0:00:44    62% |████████████████████            | 31.1MB 38.0MB/s eta 0:00:01
# ...

# %%
db_connection = sql.connect(host='localhost', database='valerios', user='root', password='root')
tables = pd.read_sql('SELECT table_name AS "Table", round(((data_length + index_length) / 1024 / 1024), 2) as SIZE FROM information_schema.TABLES WHERE table_schema = "valerios" ORDER BY SIZE;', con=db_connection)
tables=tables.query('SIZE>0.1')
tables
# Out:
#                   Table     SIZE
# 26                 user     0.25
# 27                 file     0.47
# 28  commit_in_reference     1.52
# 29        commit_parent     2.02
# 30       code_at_commit     2.52
# 31               commit     5.97
# 32   function_at_commit    35.56
# 33             function    90.22
# 34    file_modification   138.09
# 35       file_at_commit  1014.61

# %%
tabls={}
for index,row in enumerate(tables.iterrows()):
    tabls[row[1]['Table']]=pd.read_sql('SELECT * from '+str(row[1]['Table'])+';', con=db_connection)

# %%
tabls['commit'].head()
# Out:
#    id  repo_id                                       sha  \
# 0   1        1  866346e1ada583daeb649c253516c8f8a879c387
# 1   2        1  eaa397c76b7d28343cde9f3a0338b9b0e79197c8
# 2   3        1  c9c176a53b1632ca2b1c6ed27382ab72ac21d45d
# 3   4        1  fac0e698a85ade9cb6a18fd400bcbdf118d5e4eb
# 4   5        1  214c142d9de60a7f53d8c7ada2812ffff4837e0f
#
#                                              message  author_id  committer_id  \
# 0          git5: git5track synced with perforce at 0          1             1
# 1   git5: git5track synced with perforce at 16173833          1             1
# 2                                         angular.js          2             2
# 3                                        MIT license          2             2
# 4  created a way to init the code without autoboo...          3             3
#
#         authored_date      committed_date  size
# 0 1970-01-01 01:00:01 1970-01-01 01:00:01   161
# 1 1970-01-01 01:00:01 1970-01-01 01:00:01   264
# ...
